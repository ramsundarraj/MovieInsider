# %%
from bs4 import BeautifulSoup
import requests

website=requests.get("https://www.movieinsider.com/movies/2020").text
soup=BeautifulSoup(website,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link as="font" crossorigin="" href="https://fonts.googleapis.com/css?family=Montserrat:400,700" rel="preload" type="font/woff2"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:400,700" rel="stylesheet" type="text/css"/>
#   <link as="style" href="https://s.movieinsider.com/css/min-0.min_m1619125703.css" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://s.movieinsider.com/fonts/fontawesome-webfont.woff2?v=4.4.0" rel="preload" type="font/woff2"/>
#   <link as="script" href="https://s.movieinsider.com/js/min-0.min_m1600044718.js" rel="preload"/>
#   <link as="script" href="https://s.movieinsider.com/js/min-1.min_m1596338201.js" rel="preload"/>
#   <title>
#    2020 Movies - List of Movies Released in 2020
#   </title>
#   <meta content="2020 Movies: A list of movies in theaters + released in 2020. We provide 2020 movie release dates, cast, posters, trailers and ratings. Top movies 2020: Wonder Woman 1984 • Fatale • Pinocchio • Promising Young Woman" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://s.movieinsider.com/css/min-0.min_m1619125703.css" media="screen, print" rel="stylesheet"/>
#   <script data-cfasync="false" src="https://s.movieinsider.com/js/min-1.min_m1596338201.js">
#   </script>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="blue" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="object" property="og:type"/>
#   <meta content="2020 Movies - List of Movies Released in 2020 - Movie Insider" property="og:title"/>
#   <meta content="Movie Insider" property="og:site_name"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@movieinsider" name="twitter:site"/>
#   <meta content="@movieinsider" name="twitter:creator"/>
#   <meta content="2020 Movies - List of Movies Released in 2020 - Movie Insider" name="twitter:title"/>
#   <meta content="movieinsider.com" name="twitter:domain"/>
#   <meta content="2020 Movies: A list of movies in theaters + released in 2020. We provide 2020 movie release dates, cast, posters, trailers and ratings. Top movies 2020: Wonder Woman 1984 • Fatale • Pinocchio • Promising Young Woman" name="twitter:description"/>
#   <meta content="https://www.facebook.com/movieinsider" property="article:publisher"/>
#   <link href="mailto:movies@movieinsider.com" rel="me"/>
#   <link href="https://twitter.com/movieinsider" rel="me"/>
#   <meta content="Brian D. Renner" name="author"/>
#   <meta content="Movie Insider" name="application-name"/>
#   <link href="https://s.movieinsider.com/images/icons/manifest.json?v=4" rel="manifest"/>
#   <link href="https://s.movieinsider.com/favicon.ico?v=8" rel="shortcut icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="https://s.movieinsider.com/images/icons/mstile-144x144.png?v=4" name="msapplication-TileImage"/>
#   <meta content="https://s.movieinsider.com/images/icons/browserconfig.xml?v=4" name="msapplication-config"/>
#   <meta content="#4668bc" name="theme-color"/>
#   <link href="https://www.movieinsider.com/movies/2020" rel="canonical"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"WebSite","url":"https://www.movieinsider.com//","potentialAction":{"@type":"SearchAction","target":"https://www.movieinsider.com/search.php?q={search_term}","query-input":"required name=search_term"}}
#   </script>
#   <script type="application/ld+json">
#    { "@context": "http://schema.org", "@type": "Organization", "name": "Movie Insider", "url": "https://www.movieinsider.com/", "logo": "https://s.movieinsider.com/images/icons/android-chrome-144x144.png", "sameAs": [ "https://en.wikipedia.org/wiki/Movie_Insider", "https://www.facebook.com/movieinsider", "https://www.twitter.com/movieinsider", "https://www.instagram.com/movieinsider/", "https://plus.google.com/+movieinsider", "https://www.youtube.com/c/movieinsider", "https://www.linkedin.com/company/the-movie-insider-llc" ] } }
#   </script>
#   <meta content="Sat, 27 Feb 2021 18:35:04 GMT" http-equiv="last-modified"/>
#   <script data-cfasync="false">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-K2Q5763');
#   </script>
#   <script async="true" type="text/javascript">
#    (function() { var host = window.location.hostname; var element = document.createElement('script'); var firstScript = document.getElementsByTagName('script')[0]; var url = 'https://quantcast.mgr.consensu.org' .concat('/choice/', 'VpysWVBkEHYLF', '/', host, '/choice.js'); var uspTries = 0; var uspTriesLimit = 3; element.async = true; element.type = 'text/javascript'; element.src = url; firstScript.parentNode.insertBefore(element, firstScript); function makeStub() { var TCF_LOCATOR_NAME = '__tcfapiLocator'; var queue = []; var win = window; var cmpFrame; function addFrame() { var doc = win.document; var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]); if (!otherCMP) { if (doc.body) { var iframe = doc.createElement('iframe'); iframe.style.cssText = 'display:none'; iframe.name = TCF_LOCATOR_NAME; doc.body.appendChild(iframe); } else { setTimeout(addFrame, 5); } } return !otherCMP; } function tcfAPIHandler() { var gdprApplies; var args = arguments; if (!args.length) { return queue; } else if (args[0] === 'setGdprApplies') { if ( args.length > 3 && args[2] === 2 && typeof args[3] === 'boolean' ) { gdprApplies = args[3]; if (typeof args[2] === 'function') { args[2]('set', true); } } } else if (args[0] === 'ping') { var retr = { gdprApplies: gdprApplies, cmpLoaded: false, cmpStatus: 'stub' }; if (typeof args[2] === 'function') { args[2](retr); } } else { queue.push(args); } } function postMessageEventHandler(event) { var msgIsString = typeof event.data === 'string'; var json = {}; try { if (msgIsString) { json = JSON.parse(event.data); } else { json = event.data; } } catch (ignore) {} var payload = json.__tcfapiCall; if (payload) { window.__tcfapi( payload.command, payload.version, function(retValue, success) { var returnMsg = { __tcfapiReturn: { returnValue: retValue, success: success, callId: payload.callId } }; if (msgIsString) { returnMsg = JSON.stringify(returnMsg); } event.source.postMessage(returnMsg, '*'); }, payload.parameter ); } } while (win) { try { if (win.frames[TCF_LOCATOR_NAME]) { cmpFrame = win; break; } } catch (ignore) {} if (win === window.top) { break; } win = win.parent; } if (!cmpFrame) { addFrame(); win.__tcfapi = tcfAPIHandler; win.addEventListener('message', postMessageEventHandler, false); } }; if (typeof module !== 'undefined') { module.exports = makeStub; } else { makeStub(); } var uspStubFunction = function() { var arg = arguments; if (typeof window.__uspapi !== uspStubFunction) { setTimeout(function() { if (typeof window.__uspapi !== 'undefined') { window.__uspapi.apply(window.__uspapi, arg); } }, 500); } }; var checkIfUspIsReady = function() { uspTries++; if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) { console.warn('USP is not accessible'); } else { clearInterval(uspInterval); } }; if (typeof window.__uspapi === 'undefined') { window.__uspapi = uspStubFunction; var uspInterval = setInterval(checkIfUspIsReady, 6000); } })();
#   </script>
#   <script>
#    tmi_ads.assignBidders(); tmi_ads.getActiveUnits = function() { var ads_active = []; var window_width = Math.max(document.documentElement.clientWidth, window.innerWidth || 0); var getUnit = function(position, id) { var ad_bids; for (var i = 0; i < tmi_ads.units[position].bids.length; i++) { if (window_width >= tmi_ads.units[position].bids[i].minWidth) { ad_bids = tmi_ads.units[position].bids[i].bids; break; } } if (ad_bids.length > 0) { return { code: id, sizeMapping: tmi_ads.units[position].sizeMapping, mediaTypes: tmi_ads.units[position].mediaTypes, bids: ad_bids }; } return false; }; var ads_active = []; var ad_unit = getUnit('middle1', 'ROS_Middle1_Responsive'); if (ad_unit) { ads_active.push(ad_unit); } var ad_unit = getUnit('bottom', 'ROS_Bottom_Responsive'); if (ad_unit) { ads_active.push(ad_unit); } var ad_unit = getUnit('sidebar1', 'ROS_Sidebar1_Responsive'); if (ad_unit) { ads_active.push(ad_unit); } var ad_unit = getUnit('sidebar2', 'ROS_Sidebar2_Responsive'); if (ad_unit) { ads_active.push(ad_unit); } var ad_unit = getUnit('sidebar4', 'ROS_Sidebar4_Responsive'); if (ad_unit) { ads_active.push(ad_unit); } var ad_unit = getUnit('top', 'ROS_Top_Responsive'); if (ad_unit) { ads_active.push(ad_unit); } return ads_active; }; tmi_ads.setGptSizes = function(googletag) { var size_mapping = googletag.sizeMapping(); for (var i = 0; i < tmi_ads.units.middle1.sizeMapping.length; i++) { var mapping = tmi_ads.units.middle1.sizeMapping[i]; size_mapping.addSize([mapping.minWidth, mapping.minWidth ? 200 : 0], mapping.sizes); } googletag.defineSlot( tmi_ads.config.gpt_slot_prefix+'ROS_Middle1_Responsive', tmi_ads.units.middle1.mediaTypes.banner.sizes, 'ROS_Middle1_Responsive' ).defineSizeMapping(size_mapping.build()).addService(googletag.pubads()); var size_mapping = googletag.sizeMapping(); for (var i = 0; i < tmi_ads.units.bottom.sizeMapping.length; i++) { var mapping = tmi_ads.units.bottom.sizeMapping[i]; size_mapping.addSize([mapping.minWidth, mapping.minWidth ? 200 : 0], mapping.sizes); } googletag.defineSlot( tmi_ads.config.gpt_slot_prefix+'ROS_Bottom_Responsive', tmi_ads.units.bottom.mediaTypes.banner.sizes, 'ROS_Bottom_Responsive' ).defineSizeMapping(size_mapping.build()).addService(googletag.pubads()); var size_mapping = googletag.sizeMapping(); for (var i = 0; i < tmi_ads.units.sidebar1.sizeMapping.length; i++) { var mapping = tmi_ads.units.sidebar1.sizeMapping[i]; size_mapping.addSize([mapping.minWidth, mapping.minWidth ? 200 : 0], mapping.sizes); } googletag.defineSlot( tmi_ads.config.gpt_slot_prefix+'ROS_Sidebar1_Responsive', tmi_ads.units.sidebar1.mediaTypes.banner.sizes, 'ROS_Sidebar1_Responsive' ).defineSizeMapping(size_mapping.build()).addService(googletag.pubads()); var size_mapping = googletag.sizeMapping(); for (var i = 0; i < tmi_ads.units.sidebar2.sizeMapping.length; i++) { var mapping = tmi_ads.units.sidebar2.sizeMapping[i]; size_mapping.addSize([mapping.minWidth, mapping.minWidth ? 200 : 0], mapping.sizes); } googletag.defineSlot( tmi_ads.config.gpt_slot_prefix+'ROS_Sidebar2_Responsive', tmi_ads.units.sidebar2.mediaTypes.banner.sizes, 'ROS_Sidebar2_Responsive' ).defineSizeMapping(size_mapping.build()).addService(googletag.pubads()); var size_mapping = googletag.sizeMapping(); for (var i = 0; i < tmi_ads.units.sidebar4.sizeMapping.length; i++) { var mapping = tmi_ads.units.sidebar4.sizeMapping[i]; size_mapping.addSize([mapping.minWidth, mapping.minWidth ? 200 : 0], mapping.sizes); } googletag.defineSlot( tmi_ads.config.gpt_slot_prefix+'ROS_Sidebar4_Responsive', tmi_ads.units.sidebar4.mediaTypes.banner.sizes, 'ROS_Sidebar4_Responsive' ).defineSizeMapping(size_mapping.build()).addService(googletag.pubads()); var size_mapping = googletag.sizeMapping(); for (var i = 0; i < tmi_ads.units.top.sizeMapping.length; i++) { var mapping = tmi_ads.units.top.sizeMapping[i]; size_mapping.addSize([mapping.minWidth, mapping.minWidth ? 200 : 0], mapping.sizes); } googletag.defineSlot( tmi_ads.config.gpt_slot_prefix+'ROS_Top_Re ...
#   </script>
#   <script async="" id="sBeacon" src="//ap.lijit.com/www/sovrn_beacon_standalone/sovrn_standalone_beacon.js?iid=10155914&amp;uid=movieinsider">
#   </script>
#   <script>
#    tmi_ads.init(false, false);
#   </script>
#   <script async="" data-ad-client="ca-pub-9136844266644239" data-cfasync="false" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#  </head>
#  <body>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K2Q5763" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <nav class="navbar navbar-inverse navbar-fixed-top">
#    <div class="container-fluid">
#     <div class="navbar-header">
#      <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="https://www.movieinsider.com/">
#       <img alt="Movie Insider" class="img-responsive" src="https://s.movieinsider.com/images/logo.png"/>
#      </a>
#     </div>
#     <nav class="navbar-collapse collapse" id="navbar">
#      <ul class="nav navbar-nav">
#       <li class="visible-xs visible-sm">
#        <a href="https://www.movieinsider.com/">
#         <i class="fa fa-home fa-fw">
#         </i>
#         Home
#        </a>
#       </li>
#       <li class="">
#        <a href="https://www.movieinsider.com/movies-in-theaters">
#         <i class="fa fa-ticket fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         In Theaters
#        </a>
#       </li>
#       <li>
#        <a href="https://www.movieinsider.com//movies/this-week">
#         <i class="fa fa-plus fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         This Week
#        </a>
#       </li>
#       <li class="">
#        <a href="https://www.movieinsider.com/movies-coming-soon">
#         <i class="fa fa-exclamation-circle fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         Coming Up
#        </a>
#       </li>
#       <li>
#        <a href="https://www.movieinsider.com/movies/2021">
#         <i class="fa fa-calendar-plus-o fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         2021 Movies
#        </a>
#       </li>
#       <li>
#        <a href="https://www.movieinsider.com/movies/2022">
#         <i class="fa fa-calendar-plus-o fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         2022 Movies
#        </a>
#       </li>
#       <li class="dropdown active">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="https://www.movieinsider.com/lists/the-complete-list-of-all-upcoming-movie-release-dates">
#         <i class="fa fa-calendar fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         Upcoming
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu dropdown-menu-left" role="menu">
#         <li>
#          <a href="https://www.movieinsider.com/movies/2023">
#           2023 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2024">
#           2024 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/lists/the-complete-list-of-all-upcoming-movie-release-dates">
#           All Release Dates
#           <i class="fa fa-sort-amount-desc fa-fw">
#           </i>
#          </a>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li class="dropdown-header">
#          By Production Status
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/production-status/development">
#           <span class="phaser iphase2 active">
#            Development
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/production-status/pre-production">
#           <span class="phaser iphase3 active">
#            Pre-Production
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/production-status/production">
#           <span class="phaser iphase3 active">
#            Production
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/production-status/post-production">
#           <span class="phaser iphase3 active">
#            Post-Production
#           </span>
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/genres">
#           <i class="fa fa-tags fa-fw">
#           </i>
#           By Genres
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movie-studios/popular/">
#           <i class="fa fa-building fa-fw">
#           </i>
#           By Studio
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/alpha">
#           <i class="fa fa-sort-alpha-asc fa-fw">
#           </i>
#           By Title
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/mpaa">
#           <i class="fa fa-info-circle fa-fw">
#           </i>
#           By MPAA Rating
#          </a>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li class="dropdown-header">
#          Find movies by plot, person,
#          <br/>
#          company &amp; shooting location.
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/browse/movies">
#           Browse Movies
#           <i class="fa fa-chevron-circle-right fa-fw">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="">
#        <a href="https://www.movieinsider.com/movie-trailers">
#         <i class="fa fa-play-circle fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         Trailers
#        </a>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="https://www.movieinsider.com/top-movies">
#         <i class="fa fa-film fa-fw visible-xs-inline-block visible-sm-inline-block">
#         </i>
#         More
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu dropdown-menu-left" role="menu">
#         <li>
#          <a href="https://www.movieinsider.com/movie-photos">
#           <i class="fa fa-camera-retro fa-fw">
#           </i>
#           Movie Photos
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/lists">
#           <i class="fa fa-list fa-fw">
#           </i>
#           Movie Lists
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/top-movies/">
#           <i class="fa fa-bar-chart-o fa-fw">
#           </i>
#           Top Movies
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/dvds/">
#           <i class="fa fa-dot-circle-o fa-fw">
#           </i>
#           DVD Calendar
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2020">
#           2020 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2019">
#           2019 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2018">
#           2018 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2017">
#           2017 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2016">
#           2016 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2015">
#           2015 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2014">
#           2014 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2013">
#           2013 Movies
#          </a>
#         </li>
#         <li>
#          <a href="https://www.movieinsider.com/movies/2012">
#           2012 Movies
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#      <div class="social-icons visible-xs visible-sm">
#       <a aria-label="YouTube" href="https://www.youtube.com/c/movieinsider?sub_confirmation=1" rel="noopener" title="YouTube">
#        <i class="fa fa fa-youtube-play">
#        </i>
#       </a>
#       <a aria-label="Instagram" href="https://www.instagram.com/movieinsider/" title="Instagram">
#        <i class="fa fa-instagram">
#        </i>
#       </a>
#       <a aria-label="Facebook" href="https://www.facebook.com/movieinsider" title="Facebook">
#        <i class="fa fa-facebook">
#        </i>
#       </a>
#       <a aria-label="Twitter" href="https://twitter.com/intent/follow?source=followbutton&amp;variant=1.0&amp;screen_name=movieinsider" rel="noopener" title="Twitter">
#        <i class="fa fa-twitter">
#        </i>
#       </a>
#      </div>
#     </nav>
#     <div class="navbar-right">
#      <form action="https://www.movieinsider.com/search.php" class="navbar-search" role="search">
#       <div class="input-group">
#        <input aria-label="Search this site" class="form-control" id="srch-term" name="q" placeholder="Search" required="" type="text" value=""/>
#        <div class="input-group-btn">
#         <button aria-label="Search" class="btn btn-default" type="submit">
#          <i class="fa fa-search fa-lg">
#          </i>
#         </button>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#   </nav>
#   <div class="top-area clearfix">
#    <div class="container text-center">
#     <div class="ad728" id="ROS_Top_Responsive">
#      <script>
#       googletag.cmd.push(function() { googletag.display('ROS_Top_Responsive'); });
#      </script>
#     </div>
#    </div>
#   </div>
#   <div class="subpage-head">
#    <div class="container">
#     <h1>
#      2020 Movies
#     </h1>
#     <p class="lead alignright">
#      Complete List of All New 2020 Movies Released In Theaters
#     </p>
#    </div>
#   </div>
#   <div class="main container" id="main" tabindex="-1">
#    <div class="row">
#     <div class="layout-2cols pt-hight clearfix">
#      <main class="col-md-8 content has-margin-xs-top has-margin-xs-bottom">
#       <div class="pull-right social btn-group share-group" id="socialShare">
#        <a class="btn btn-xs btn-primary" data-toggle="dropdown">
#         <i class="fa fa-share-alt">
#         </i>
#         Share
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="btn btn-facebook" data-original-title="Facebook" data-placement="left" href="https://www.facebook.com/sharer/sharer.php?u=http%3A%2F%2Fwww.movieinsider.com&amp;t=" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u=' + encodeURIComponent(document.URL) + '&amp;t=' + encodeURIComponent(document.URL)); return false;" rel="nofollow noopener popup:external" target="_blank" title="Share on Facebook">
#           <i class="fa fa-facebook">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="btn btn-twitter" data-original-title="Twitter " data-placement="left" href="https://twitter.com/intent/tweet?source=http%3A%2F%2Fwww.movieinsider.com&amp;text=:%20https%3A%2F%2Fwww.movieinsider.com&amp;via=movieinsider" onclick="if (!window.__cfRLUnblockHandlers) return false; window.open('https://twitter.com/intent/tweet?text=' + encodeURIComponent(document.title) + ':%20' + encodeURIComponent(document.URL) + '?twitter%20via @movieinsider'); return false;" rel="nofollow noopener popup:external" target="_blank" title="Tweet">
#           <i class="fa fa-twitter">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a aria-label="Share on LinkedIn" class="btn btn-linkedin" data-placement="left" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http%3A%2F%2Fwww.movieinsider.com&amp;t=" onclick="window.open('https://www.linkedin.com/shareArticle?mini=true&amp;url=' + encodeURIComponent(document.URL) + '&amp;t=' + encodeURIComponent(document.URL)); return false;" rel="nofollow noopener popup:external">
#           <i class="fa fa-linkedin">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="btn btn-pinterest" data-original-title="Pinterest" data-placement="left" href="https://pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.movieinsider.com&amp;description=" onclick="if (!window.__cfRLUnblockHandlers) return false; window.open('https://pinterest.com/pin/create/button/?url=' + encodeURIComponent(document.URL) + '?pinterest&amp;description=' + encodeURIComponent(document.title)); return false;" rel="nofollow noopener popup:external" target="_blank" title="Pin it">
#           <i class="fa fa-pinterest">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="btn btn-mail" data-original-title="Email" data-placement="left" href="mailto:?subject=&amp;body=:%20https%3A%2F%2Fwww.movieinsider.com" onclick="if (!window.__cfRLUnblockHandlers) return false; window.open('mailto:?subject=' + encodeURIComponent(document.title) + '%20onMovie%20Insider&amp;body=Check%20out%20this%20link%20on%20Movie%20Insider:%20' + encodeURIComponent(document.URL) + '?email'); return false;" rel="nofollow noopener popup:external" title="Send email">
#           <i class="fa fa-envelope">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="page-top">
#        <p class="author-date-top">
#         <img alt="Brian D Renner photo" class="img-circle" src="https://s.movieinsider.com/images/author-brenner.png"/>
#         <span>
#          By
#          <a href="https://www.movieinsider.com/contact/#brian">
#           Brian D. Renner
#          </a>
#         </span>
#         <span>
#          <i aria-hidden="true" class="fa fa-clock-o">
#          </i>
#          Feb. 27, 2021
#         </span>
#        </p>
#        <p>
#        </p>
#       </div>
#       <div class="page-utilities">
#        <div class="actions">
#         <div class="btn-group">
#          <button aria-expanded="false" class="btn btn-default dropdown-toggle" data-toggle="dropdown" type="button">
#           2020
#           <span class="caret">
#           </span>
#          </button>
#          <ul class="dropdown-menu scrollable-menu">
#           <li>
#            <a href="/movies/2028?view=list">
#             2028
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2027?view=list">
#             2027
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2026?view=list">
#             2026
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2025?view=list">
#             2025
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2024?view=list">
#             2024
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2023?view=list">
#             2023
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2022?view=list">
#             2022
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2021?view=list">
#             2021
#            </a>
#           </li>
#           <li class="disabled">
#            <a href="/movies/2020?view=list">
#             2020
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2019?view=list">
#             2019
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2018?view=list">
#             2018
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2017?view=list">
#             2017
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2016?view=list">
#             2016
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2015?view=list">
#             2015
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2014?view=list">
#             2014
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2013?view=list">
#             2013
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2012?view=list">
#             2012
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2011?view=list">
#             2011
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2010?view=list">
#             2010
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2009?view=list">
#             2009
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2008?view=list">
#             2008
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2007?view=list">
#             2007
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2006?view=list">
#             2006
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2005?view=list">
#             2005
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2004?view=list">
#             2004
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2003?view=list">
#             2003
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2002?view=list">
#             2002
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2001?view=list">
#             2001
#            </a>
#           </li>
#           <li>
#            <a href="/movies/2000?view=list">
#             2000
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1999?view=list">
#             1999
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1998?view=list">
#             1998
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1997?view=list">
#             1997
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1996?view=list">
#             1996
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1995?view=list">
#             1995
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1994?view=list">
#             1994
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1993?view=list">
#             1993
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1991?view=list">
#             1991
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1990?view=list">
#             1990
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1988?view=list">
#             1988
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1985?view=list">
#             1985
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1984?view=list">
#             1984
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1983?view=list">
#             1983
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1982?view=list">
#             1982
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1980?view=list">
#             1980
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1977?view=list">
#             1977
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1975?view=list">
#             1975
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1972?view=list">
#             1972
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1965?view=list">
#             1965
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1961?view=list">
#             1961
#            </a>
#           </li>
#           <li>
#            <a href="/movies/1956?view=list">
#             1956
#            </a>
#           </li>
#           <li>
#            <a href="/movies/tba/tba?view=list">
#             TBA
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="btn-group">
#          <button aria-expanded="false" class="btn btn-default active dropdown-toggle" data-toggle="dropdown" type="button">
#           <i class="fa fa-fw fa-calendar-o fa-fw">
#           </i>
#           All Months
#           <span class="caret">
#           </span>
#          </button>
#          <ul class="dropdown-menu scrollable-menu">
#           <li class="disabled">
#            <a href="/movies/2020?view=list">
#             All Months
#            </a>
#           </li>
#           <li>
#            <a href="/movies/january/2020?view=list">
#             January
#            </a>
#           </li>
#           <li>
#            <a href="/movies/february/2020?view=list">
#             February
#            </a>
#           </li>
#           <li>
#            <a href="/movies/march/2020?view=list">
#             March
#            </a>
#           </li>
#           <li>
#            <a href="/movies/april/2020?view=list">
#             April
#            </a>
#           </li>
#           <li>
#            <a href="/movies/may/2020?view=list">
#             May
#            </a>
#           </li>
#           <li>
#            <a href="/movies/june/2020?view=list">
#             June
#            </a>
#           </li>
#           <li>
#            <a href="/movies/july/2020?view=list">
#             July
#            </a>
#           </li>
#           <li>
#            <a href="/movies/august/2020?view=list">
#             August
#            </a>
#           </li>
#           <li>
#            <a href="/movies/september/2020?view=list">
#             September
#            </a>
#           </li>
#           <li>
#            <a href="/movies/october/2020?view=list">
#             October
#            </a>
#           </li>
#           <li>
#            <a href="/movies/november/2020?view=list">
#             November
#            </a>
#           </li>
#           <li>
#            <a href="/movies/december/2020?view=list">
#             December
#            </a>
#           </li>
#           <li>
#            <a href="/movies/tba/2020?view=list">
#             TBA
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="btn-group">
#          <button aria-controls="collapseFilter" aria-expanded="false" class="btn btn-default" data-toggle="collapse" href="#collapseFilter">
#           <i class="fa fa-filter">
#           </i>
#           Filter
#           <i class="fa fa-caret-right">
#           </i>
#          </button>
#         </div>
#        </div>
#        <div class="page-nav">
#         <div class="btn-group" role="group">
#          <a class="btn btn-default active" data-original-title="List View" href="/movies/2020?view=list">
#           <i class="fa fa-list-ul">
#           </i>
#           List
#          </a>
#          <a class="btn btn-default" data-original-title="Grid View" href="/movies/2020?view=grid">
#           <i class="fa fa-th-large">
#           </i>
#           Grid
#          </a>
#         </div>
#        </div>
#        <form class="form-inline" method="get">
#         <input name="view" type="hidden" value="list"/>
#         <div class="calendar-filters">
#          <div class="collapse well has-margin-xs-top has-margin-xs-bottom" id="collapseFilter">
#           <div class="row">
#            <div class="col-xs-6 col-sm-3">
#             <label for="calendar-filter-scope">
#              <small>
#               <i class="fa fa-fw fa-map">
#               </i>
#               Scope
#              </small>
#             </label>
#             <br/>
#             <select class="form-control" name="scope" onchange='$(this).closest("form").submit()'>
#              <option value="">
#               All
#              </option>
#              <option value="1">
#               Nationwide
#              </option>
#              <option value="2">
#               Limited
#              </option>
#              <option value="3">
#               - New York / Los Angeles
#              </option>
#              <option value="4">
#               - New York
#              </option>
#              <option value="5">
#               - Los Angeles
#              </option>
#              <option value="8">
#               - Oscar Run
#              </option>
#              <option value="13">
#               - Expansion
#              </option>
#              <option value="16">
#               - 1 Day Only
#              </option>
#              <option value="23">
#               - Drive-In
#              </option>
#              <option value="9">
#               VOD / Digital
#              </option>
#              <option value="14">
#               - Netflix
#              </option>
#              <option value="17">
#               - Hulu
#              </option>
#              <option value="18">
#               - Disney+
#              </option>
#              <option value="20">
#               - PrimeVideo
#              </option>
#              <option value="21">
#               - HBO Max
#              </option>
#              <option value="22">
#               - Apple TV+
#              </option>
#              <option value="24">
#               - PremiumVOD
#              </option>
#              <option value="25">
#               - Paramount+
#              </option>
#              <option value="26">
#               - Disney+ Premier
#              </option>
#             </select>
#            </div>
#            <div class="col-xs-6 col-sm-4">
#             <label for="calendar-filter-genre">
#              <small>
#               <i class="fa fa-fw fa-tags">
#               </i>
#               Genres
#              </small>
#             </label>
#             <br/>
#             <select class="form-control" name="genre" onchange='$(this).closest("form").submit()'>
#              <option value="">
#               All (635)
#              </option>
#              <option value="170">
#               2D
#              </option>
#              <option value="150">
#               3D (1)
#              </option>
#              <option value="4">
#               Action (66)
#              </option>
#              <option value="20">
#               Adaptation (37)
#              </option>
#              <option value="5">
#               Adventure (43)
#              </option>
#              <option value="35">
#               Animation (27)
#              </option>
#              <option value="202">
#               Baseball
#              </option>
#              <option value="217">
#               Based on Book
#              </option>
#              <option value="196">
#               Based on Game (2)
#              </option>
#              <option value="206">
#               Based on Play (5)
#              </option>
#              <option value="200">
#               Based on Toy
#              </option>
#              <option value="208">
#               Based on TV (2)
#              </option>
#              <option value="205">
#               Basketball
#              </option>
#              <option value="13">
#               Biography (10)
#              </option>
#              <option value="222">
#               Bollywood-Tamil
#              </option>
#              <option value="159">
#               CG (3)
#              </option>
#              <option value="107">
#               College
#              </option>
#              <option value="7">
#               Comedy (115)
#              </option>
#              <option value="199">
#               Comic Book (3)
#              </option>
#              <option value="197">
#               Coming-of-Age (5)
#              </option>
#              <option value="146">
#               Concert (2)
#              </option>
#              <option value="182">
#               Cop (1)
#              </option>
#              <option value="17">
#               Crime (37)
#              </option>
#              <option value="116">
#               Dance
#              </option>
#              <option value="181">
#               Dark Comedy (2)
#              </option>
#              <option value="171">
#               Detective
#              </option>
#              <option value="165">
#               Direct-to-Video
#              </option>
#              <option value="23">
#               Disaster (1)
#              </option>
#              <option value="37">
#               Documentary (76)
#              </option>
#              <option value="1">
#               Drama (251)
#              </option>
#              <option value="192">
#               Dramedy (1)
#              </option>
#              <option value="156">
#               Ensemble
#              </option>
#              <option value="22">
#               Epic
#              </option>
#              <option value="216">
#               Event (2)
#              </option>
#              <option value="149">
#               Fairy Tale (1)
#              </option>
#              <option value="176">
#               Faith (3)
#              </option>
#              <option value="33">
#               Family (40)
#              </option>
#              <option value="9">
#               Fantasy (21)
#              </option>
#              <option value="221">
#               Fighting
#              </option>
#              <option value="204">
#               Football
#              </option>
#              <option value="49">
#               Foreign
#              </option>
#              <option value="212">
#               Found-Footage
#              </option>
#              <option value="29">
#               Gangster (1)
#              </option>
#              <option value="201">
#               Gross-Out Comedy
#              </option>
#              <option value="41">
#               Heist
#              </option>
#              <option value="162">
#               Hijinks (1)
#              </option>
#              <option value="12">
#               Historical (3)
#              </option>
#              <option value="203">
#               Hockey
#              </option>
#              <option value="56">
#               Holiday (8)
#              </option>
#              <option value="15">
#               Horror (80)
#              </option>
#              <option value="160">
#               Hostage
#              </option>
#              <option value="188">
#               IMAX (3)
#              </option>
#              <option value="175">
#               Invasion
#              </option>
#              <option value="34">
#               Kids (2)
#              </option>
#              <option value="105">
#               LGBT (6)
#              </option>
#              <option value="168">
#               Live-Action/CGI (2)
#              </option>
#              <option value="61">
#               Martial Arts (1)
#              </option>
#              <option value="167">
#               Mockumentary
#              </option>
#              <option value="174">
#               Motion Capture
#              </option>
#              <option value="44">
#               Music (9)
#              </option>
#              <option value="27">
#               Musical (12)
#              </option>
#              <option value="43">
#               Mystery (18)
#              </option>
#              <option value="38">
#               Nature (2)
#              </option>
#              <option value="62">
#               Noir
#              </option>
#              <option value="215">
#               Opera
#              </option>
#              <option value="193">
#               Paranormal
#              </option>
#              <option value="66">
#               Period (10)
#              </option>
#              <option value="51">
#               Political (10)
#              </option>
#              <option value="155">
#               Post-3D
#              </option>
#              <option value="36">
#               Prequel
#              </option>
#              <option value="40">
#               Provocative
#              </option>
#              <option value="76">
#               Psychological (2)
#              </option>
#              <option value="211">
#               Re-Release (3)
#              </option>
#              <option value="148">
#               Reboot (2)
#              </option>
#              <option value="19">
#               Remake (8)
#              </option>
#              <option value="161">
#               Road Trip (1)
#              </option>
#              <option value="16">
#               Romance (55)
#              </option>
#              <option value="69">
#               Romantic Comedy (6)
#              </option>
#              <option value="93">
#               Satire (2)
#              </option>
#              <option value="32">
#               Sci-Fi (32)
#              </option>
#              <option value="8">
#               Sequel (10)
#              </option>
#              <option value="183">
#               Short
#              </option>
#              <option value="154">
#               Shot-In-3D (1)
#              </option>
#              <option value="42">
#               Spin-off (2)
#              </option>
#              <option value="46">
#               Spoof
#              </option>
#              <option value="24">
#               Sports (5)
#              </option>
#              <option value="39">
#               Spy (2)
#              </option>
#              <option value="187">
#               Stop-Motion
#              </option>
#              <option value="18">
#               Superhero (4)
#              </option>
#              <option value="47">
#               Supernatural (4)
#              </option>
#              <option value="11">
#               Suspense (10)
#              </option>
#              <option value="28">
#               Teen (12)
#              </option>
#              <option value="10">
#               Thriller (136)
#              </option>
#              <option value="209">
#               Time Travel
#              </option>
#              <option value="164">
#               True Story (11)
#              </option>
#              <option value="158">
#               Vampires
#              </option>
#              <option value="6">
#               War (11)
#              </option>
#              <option value="14">
#               Western (2)
#              </option>
#              <option value="157">
#               Zombies (2)
#              </option>
#             </select>
#            </div>
#            <div class="col-xs-12 col-sm-5">
#             <label for="calendar-filter-plot">
#              <small>
#               <i class="fa fa-fw fa-film">
#               </i>
#               Title/Plot or
#               <i class="fa fa-fw fa-user">
#               </i>
#               Person
#              </small>
#             </label>
#             <br/>
#             <div class="calendar-filter-plot-wrapper">
#              <div class="input-group">
#               <input class="form-control" id="calendar-filter-plot" name="plot" placeholder="Search" type="text" value=""/>
#               <div class="input-group-btn">
#                <button aria-label="Search" class="btn btn-default" type="submit">
#                 <i class="fa fa-search fa-lg">
#                 </i>
#                </button>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="calendar-teases has-margin-xs-top">
#           <h2 class="section-title">
#            The Top &amp; Best 2020 Movies
#            <a href="https://www.movieinsider.com/movies/popular/2020">
#             <i class="fa fa-link fa-fw">
#             </i>
#            </a>
#           </h2>
#           <div class="row calendar-teases calendar-carousel">
#            <div class="col-xs-4 col-md-2">
#             <div class="thumbnail">
#              <a href="https://www.movieinsider.com/m18916/pinocchio">
#               <img alt="Pinocchio Movie" class="img-responsive" src="https://s.movieinsider.com/images/p/150/573773_m1608141760.jpg"/>
#              </a>
#              <div class="caption text-center">
#               <h6>
#                <a href="https://www.movieinsider.com/m18916/pinocchio">
#                 Pinocchio
#                </a>
#               </h6>
#              </div>
#             </div>
#            </div>
#            <div class="col-xs-4 col-md-2">
#             <div class="thumbnail">
#              <a href="https://www.movieinsider.com/m16722/fatale">
#               <img alt="Fatale Movie" class="img-responsive" src="https://s.movieinsider.com/images/p/150/572482_m1607025005.png"/>
#              </a>
#              <div class="caption text-center">
#               <h6>
#                <a href="https://www.movieinsider.com/m16722/fatale">
#                 Fatale
#                </a>
#               </h6>
#              </div>
#             </div>
#            </div>
#            <div class="col-xs-4 col-md-2">
#             <div class="thumbnail">
#              <a href="https://www.movieinsider.com/m18842/vanguard">
#               <img alt="Vanguard Movie" class="img-responsive" src="https://s.movieinsider.com/images/p/150/569576_m1604246285.jpg"/>
# ...
#               <a href="https://www.movieinsider.com/m19198/here-today/videos/15752">
#                <div class="fa fa-play-circle-o fa-3x play-overlay">
#                </div>
#                <img alt="Here Today" class="img-responsive" src="https://s.movieinsider.com/images/ytimg/U3v8n_8-QqA/hqdefault_m1619447489.jpg"/>
#               </a>
#              </div>
#              <p class="media-heading">
#               <a href="https://www.movieinsider.com/m19198/here-today/videos/15752">
#                Here Today
#               </a>
#              </p>
#              <p class="small text-muted">
#               Official Trailer
#              </p>
#             </div>
#            </div>
#            <div class="clear">
#            </div>
#            <div class="sidebar-section sidebar-ad300">
#             <div class="ad300" id="ROS_Sidebar4_Responsive">
#              <script>
#               googletag.cmd.push(function() { googletag.display('ROS_Sidebar4_Responsive'); });
#              </script>
#             </div>
#             <p class="text-muted text-uppercase small">
#              Advertisement
#             </p>
#            </div>
#            <div class="sidebar-section sidebar-boxoffice">
#             <p>
#              <a href="https://www.movieinsider.com/movies-in-theaters/#boxoffice">
#               Weekend Box Office: Top 10
#              </a>
#             </p>
#             <p class="small">
#              Limited box office receipts reported due to continued COVID-19 pandemic.
#             </p>
#             <div class="table-responsive has-side-padding">
#              <table class="table table-hover">
#               <tbody id="sidebar-boxoffice-items">
#                <tr>
#                 <td>
#                  1.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m13635/godzilla-vs-kong">
#                   Godzilla vs. Ko...
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $8 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  2.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m16125/nobody">
#                   Nobody
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $3 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  3.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m17865/shrine">
#                   The Unholy
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $2 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  4.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m17786/raya-and-the-last-dragon">
#                   Raya and the La...
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $2 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  5.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m5736/tom-and-jerry">
#                   Tom and Jerry
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $1 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  6.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m17414/voyagers">
#                   Voyagers
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $1 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  7.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m19208/the-girl-who-believes-in-miracles">
#                   The Girl Who Be...
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $1 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  8.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m19137/in-the-earth">
#                   In The Earth
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $1 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  9.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m16402/the-courier">
#                   The Courier
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $0 million
#                  </small>
#                 </td>
#                </tr>
#                <tr>
#                 <td>
#                  10.
#                 </td>
#                 <td>
#                  <a href="https://www.movieinsider.com/m11545/the-croods-2">
#                   The Croods: A N...
#                  </a>
#                 </td>
#                 <td class="text-right">
#                  <small>
#                   &lt; $0 million
#                  </small>
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </div>
#            </div>
#           </aside>
#          </div>
#         </div>
#        </form>
#       </div>
#       <div class="highlight-bg-footer">
#        <div class="container">
#         <div class="form-group col-md-9 col-md-offset-2 has-margin-xs-top">
#          <div class="row">
#           <form action="//movieinsider.us2.list-manage.com/subscribe/post?u=6a2b42fdf82a067f9504a804d&amp;id=668483aeeb" class="form subscribe-form" id="embedded-subscribe-form" method="post" name="embedded-subscribe-form">
#            <div class="form-group col-md-4">
#             <h5 class="subscribe-head">
#              Get the
#              <span class="yellow-highlight">
#               latest on upcoming movies
#              </span>
#              before everyone else!
#             </h5>
#            </div>
#            <div class="col-md-7">
#             <div class="input-group">
#              <input aria-label="Email" class="form-control" data-validate="validate(required, email)" id="mce-EMAIL" name="EMAIL" placeholder="Email Address" required="" type="email"/>
#              <span class="input-group-btn">
#               <button class="btn btn btn-primary" type="submit">
#                Subscribe Now
#                <i class="fa fa-angle-double-right">
#                </i>
#               </button>
#              </span>
#             </div>
#            </div>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <footer>
#        <div class="container">
#         <div class="row">
#          <div class="col-sm-6 col-md-3">
#           <div class="has-margin-xs-top has-margin-xs-bottom">
#            <a href="https://www.movieinsider.com/">
#             <img alt="Movie Insider" class="img-responsive" src="https://s.movieinsider.com/images/logo.png"/>
#            </a>
#           </div>
#           <p>
#            <a href="https://en.wikipedia.org/wiki/Movie_Insider">
#             <i aria-label="Wikipedia" class="fa fa-wikipedia-w">
#             </i>
#            </a>
#            e track upcoming movies through all stages of film production.
#            <a href="https://www.movieinsider.com/contact/#aboutus">
#             Our story
#             <i class="fa fa-angle-right">
#             </i>
#            </a>
#            <br/>
#            <br/>
#            <a class="btn btn-primary" href="https://www.movieinsider.com/contact/" role="button">
#             <i class="fa fa-envelope-o fa-fw">
#             </i>
#             Email Us
#            </a>
#            <br/>
#            <small>
#             Call Us:
#             <a href="tel:248-387-9826">
#              <i class="fa fa-phone fa-fw">
#              </i>
#              248.387.9826
#             </a>
#            </small>
#           </p>
#          </div>
#          <div class="col-xs-6 col-md-2">
#           <h5>
#            Popular Lists
#           </h5>
#           <ul class="footer-links">
#            <li>
#             <a href="https://www.movieinsider.com/lists/all-upcoming-movies-in-production-pre-filming-post">
#              Top In Production
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/lists/most-popular-marvel-superhero-movies">
#              Top Marvel Movies
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/lists/dc-entertainment-movies-in-development-production">
#              Top DC Movies
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/lists/list-of-all-star-wars-movies">
#              Top Star Wars Movies
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/lists/upcoming-movie-sequels-youll-want-to-see">
#              Top Sequels
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-xs-6 col-md-3">
#           <h5>
#            Top Studios
#           </h5>
#           <ul class="footer-links">
#            <li>
#             <a href="https://www.movieinsider.com/c8/sony-pictures">
#              Sony Pictures
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/c13/universal-pictures">
#              Universal Pictures
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/c20/lionsgate-films">
#              Lionsgate
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/c4/warner-bros-pictures">
#              Warner Bros. Pictures
#             </a>
#            </li>
#            <li>
#             <a href="https://www.movieinsider.com/c3899/netflix">
#              Netflix Originals
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-xs-12 col-md-4">
#           <h5>
#            Let's Be Friends
#           </h5>
#           <div class="social-icons">
#            <a aria-label="YouTube" href="https://www.youtube.com/c/movieinsider?sub_confirmation=1" rel="noopener" title="YouTube">
#             <i class="fa fa fa-youtube-play">
#             </i>
#            </a>
#            <a aria-label="Instagram" href="https://www.instagram.com/movieinsider/" title="Instagram">
#             <i class="fa fa-instagram">
#             </i>
#            </a>
#            <a aria-label="Facebook" href="https://www.facebook.com/movieinsider" title="Facebook">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#            <a aria-label="Twitter" href="https://twitter.com/intent/follow?source=followbutton&amp;variant=1.0&amp;screen_name=movieinsider" rel="noopener" title="Twitter">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#            <a aria-label="Pinterest" href="https://www.pinterest.com/movieinsider/" title="Pinterest">
#             <i class="fa fa-pinterest">
#             </i>
#            </a>
#            <a aria-label="LinkedIn" href="https://www.linkedin.com/company/the-movie-insider-llc" title="LinkedIn">
#             <i class="fa fa-linkedin">
#             </i>
#            </a>
#            <a aria-label="RSS" href="https://www.movieinsider.com/contact/#rss" title="RSS">
#             <i class="fa fa-rss">
#             </i>
#            </a>
#            <a aria-label="Newsletter" href="https://www.movieinsider.com/contact/#newsletter" title="Newsletter">
#             <i class="fa fa-envelope">
#             </i>
#            </a>
#           </div>
#           <h5>
#            Mentioned In
#           </h5>
#           <p>
#            <a href="https://www.usatoday.com/story/life/movies/2018/07/25/hollywoods-10-most-sought-after-actors-dwayne-johnson-tiffany-haddish/789790002/">
#             USA TODAY
#            </a>
#            &amp;bullet;
#            <a href="https://www.latimes.com/archives/la-xpm-2002-oct-01-et-gold1-story.html">
#             L.A. Times
#            </a>
#            &amp;bullet;
#            <a href="https://detroit.cbslocal.com/2013/12/04/passion-for-movies-leads-to-entrepreneurial-success-online/">
#             CBS Detroit
#            </a>
#            &amp;bullet;
#            <a href="https://www.crainsdetroit.com/article/20070331/AWARDS20/150209938/brian-renner-21">
#             Crains Detroit Business
#            </a>
#            &amp;bullet;
#            <a href="https://www.corpmagazine.com/interest/entrepreneurs-executives/most-valuable-awards-showcases-the-very-best-in-a-growing-economy/">
#             Corp Magazine
#            </a>
#           </p>
#          </div>
#         </div>
#         <div class="small copyright has-margin-top has-padding-vertical">
#          © 1999—2021 The Movie Insider LLC.
#          <a href="https://www.movieinsider.com/contact/#terms">
#           Terms–DMCA
#          </a>
#          <span class="text-muted">
#           |
#          </span>
#          <a href="https://www.movieinsider.com/contact/#privacy">
#           Privacy–Cookie Policy
#          </a>
#          <span class="text-muted">
#           |
#          </span>
#          <a href="https://liquidweb.i3f2.net/DPW6y">
#           Powered by: LiquidWeb
#          </a>
#          <br/>
#          <span class="text-muted">
#           Movie Insider ® is a registered mark of The Movie Insider LLC.
#          </span>
#          <input name="__csrf__" type="hidden" value="49dde8e00eafd17819a3e359800f3d1262023c0b7adc815d7092a1cce250dd2d"/>
#         </div>
#         <a href="#top" id="scrollUp" style="position: fixed; z-index: 2147483647;">
#          <i aria-label="Scroll to top" class="fa fa-angle-up">
#          </i>
#         </a>
#        </div>
#       </footer>
#       <script>
#        var TMI_SETTINGS = { host: 'https://www.movieinsider.com/' };
#       </script>
#       <script src="https://s.movieinsider.com/js/min-0.min_m1600044718.js">
#       </script>
#       <script>
#        $(document).ready(function(){ (function(){ var carousel = $(".calendar-carousel"); var num_slides = 7; var limit = 7; var done = (num_slides < limit); var loading = false; carousel.slick({ infinite: false /* not infinite because scrolling backwards causes the ajax load to cause weird ui behaviour, and causes slick to lose slides at the start when adding the last non-complete set of slides to the end */ ,slidesToShow: 6 ,slidesToScroll: 6 ,dots: false /* don't show dots as they just keep expanding as more slides are added */ ,prevArrow: '<a class="slick-prev slick-arrow" aria-label="Previous"><span class="fa fa-chevron-left"></span></a>' ,nextArrow: '<a class="slick-next slick-arrow" aria-label="Next"><span class="fa fa-chevron-right"></span></a>' ,responsive: [ { breakpoint: 990, settings: { slidesToShow: 3 ,slidesToScroll: 3 ,infinite: false ,dots: false } } ] }) .on('beforeChange', function(event, slick, current_slide, next_slide){ if (!done && !loading && next_slide + 10 > num_slides) { loading = true; $.ajax({ url: '/ajax/movies/teases' , data: { release_type: 1 , photo_type: 1 , limit: 7 , year: 2020 , month: null , days: null , offset: num_slides } , success: function(data){ slick.slickAdd(data.teases); num_slides += data.num; done = data.num < limit; loading = false; } }); } }); })(); });
#       </script>
#      </main>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
#testing only for 2020 year
ls=[]
for title in soup.find_all('div',class_='col-xs-7 col-md-5'):
    name=title.a.text
    ls.append(name)
dict={}

# %%
# now getting movies from year 2010 to 2020
for i in range(2010,2021,1):
    website=requests.get("https://www.movieinsider.com/movies/%s" %i).text
    soup=BeautifulSoup(website,'lxml')
    for title in soup.find_all('div',class_='col-xs-7 col-md-5'):
        name=title.a.text
        dict[name]=i

# %%
dict
# Out:
# {' Youth in Revolt ': 2010,
#  ' Leap Year ': 2011,
#  ' Daybreakers ': 2010,
#  ' Wonderful World ': 2010,
#  ' The Loss of a Teardrop Diamond ': 2010,
#  ' Bitch Slap ': 2010,
#  ' Crazy on the Outside ': 2010,
#  ' The Book of Eli ': 2010,
#  ' The Spy Next Door ': 2010,
#  ' 44 Inch Chest ': 2010,
#  ' Fish Tank ': 2010,
#  ' The Last Station ': 2010,
#  ' Chance Pe Dance ': 2010,
#  ' House of Numbers ': 2010,
#  ' Legion ': 2010,
#  ' Tooth Fairy ': 2010,
#  ' Extraordinary Measures ': 2010,
#  ' The Paranoids ': 2010,
#  ' To Save a Life ': 2010,
#  ' Creation ': 2010,
#  ' The Weathered Underground ': 2010,
#  ' When in Rome ': 2010,
#  ' Edge of Darkness ': 2010,
#  ' Falling Awake ': 2010,
#  ' Off and Running ': 2010,
#  ' Saint John of Las Vegas ': 2010,
#  ' Dread ': 2010,
#  " Preacher's Kid ": 2010,
#  ' Dear John ': 2010,
#  ' From Paris with Love ': 2010,
#  ' Frozen ': 2013,
#  ' District 13: Ultimatum ': 2010,
#  ' The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers ': 2010,
#  ' Percy Jackson & the Olympians: The Lightning Thief ': 2010,
#  ' The Wolfman ': 2010,
#  " Valentine's Day ": 2010,
#  ' My Name is Khan ': 2010,
#  ' Shutter Island ': 2010,
#  ' The Ghost Writer ': 2010,
#  ' The Good Guy ': 2010,
#  ' Cop Out ': 2010,
#  ' The Crazies ': 2010,
#  ' Formosa Betrayed ': 2010,
#  ' A Prophet ': 2010,
#  ' Yellow Handkerchief ': 2010,
#  ' Alice in Wonderland ': 2010,
#  " Brooklyn's Finest ": 2010,
#  ' The Secret of Kells ': 2010,
#  ' Green Zone ': 2010,
#  ' Remember Me ': 2010,
#  " She's Out of My League ": 2010,
#  ' Our Family Wedding ': 2010,
#  ' Tales from the Script ': 2010,
#  ' The Exploding Girl ': 2010,
#  ' Stolen ': 2010,
#  ' Mother ': 2010,
#  ' Mid-August Lunch ': 2010,
#  ' Repo Men ': 2010,
#  ' Diary of a Wimpy Kid ': 2010,
#  ' The Bounty Hunter ': 2010,
#  ' The Red Baron ': 2010,
#  ' Greenberg ': 2010,
#  ' City Island ': 2010,
#  ' The Runaways ': 2010,
#  ' The Killing Jar ': 2010,
#  ' Hubble 3D ': 2010,
#  ' The Girl with the Dragon Tattoo ': 2011,
#  ' Vincere ': 2010,
#  ' How to Train Your Dragon ': 2010,
#  ' Hot Tub Time Machine ': 2010,
#  ' Lbs. ': 2010,
#  ' Dancing Across Borders ': 2010,
#  ' The Eclipse ': 2010,
#  ' Chloe ': 2010,
#  ' Ca$h ': 2010,
#  ' Waking Sleeping Beauty ': 2010,
#  ' The Last Song ': 2010,
#  ' Clash of the Titans ': 2010,
#  " Tyler Perry's Why Did I Get Married Too ": 2010,
#  ' The Greatest ': 2010,
#  ' Warlords ': 2010,
#  ' Date Night ': 2010,
#  ' Letters to God ': 2010,
#  ' Women Without Men ': 2010,
#  ' The Square ': 2017,
#  ' After.Life ': 2010,
#  " Valley of the Heart's Delight ": 2010,
#  ' La Mission ': 2010,
#  " When You're Strange ": 2010,
#  ' Kick-Ass ': 2010,
#  ' Death at a Funeral ': 2010,
#  ' No One Knows About Persian Cats ': 2010,
#  ' The City of Your Final Destination ': 2010,
#  ' The Perfect Game ': 2010,
#  ' The Joneses ': 2010,
#  ' Malice in Wonderland ': 2010,
#  ' Handsome Harry ': 2010,
#  ' El Secreto de Sus Ojos ': 2010,
#  ' Exit Through the Gift Shop ': 2010,
#  " Cheech & Chong's Hey Watch This ": 2010,
#  ' Kenny Chesney: Summer in 3D ': 2010,
#  ' Oceans ': 2010,
#  ' The Losers ': 2010,
#  ' The Back-Up Plan ': 2010,
#  ' The Good, The Bad, The Weird ': 2010,
#  ' Behind the Burly Q ': 2010,
#  ' Boogie Woogie ': 2010,
#  ' Paper Man ': 2010,
#  ' Best Worst Movie ': 2010,
#  " Hey, Hey, It's Esther Blueburger ": 2010,
#  " Anton Chekhov's The Duel ": 2010,
#  ' A Nightmare On Elm Street ': 2010,
#  ' Furry Vengeance ': 2010,
#  ' Mercy ': 2010,
#  ' The Human Centipede (First Sequence) ': 2010,
#  ' The Good Heart ': 2010,
#  ' Harry Brown ': 2010,
#  ' Phish 3D ': 2010,
#  ' Please Give ': 2010,
#  ' Sex & Drugs & Rock & Roll ': 2010,
#  ' Iron Man 2 ': 2010,
#  ' Happiness Runs ': 2010,
#  ' Babies ': 2010,
#  ' Badmaash Company ': 2010,
#  ' Casino Jack and the United States of Money ': 2010,
#  ' Mother and Child ': 2010,
#  ' Multiple Sarcasms ': 2010,
#  ' Robin Hood ': 2018,
#  ' Just Wright ': 2010,
#  ' Letters to Juliet ': 2010,
#  ' Daddy Longlegs ': 2010,
#  ' Looking for Eric ': 2010,
#  ' TiMER ': 2010,
#  ' Princess Kaiulani ': 2010,
#  ' Shrek Forever After ': 2010,
#  ' MacGruber ': 2010,
#  ' The Father of My Children ': 2010,
#  ' After the Cup: Sons of Sakhnin United ': 2010,
#  ' Solitary Man ': 2010,
#  ' Holy Rollers ': 2010,
#  ' Kites ': 2010,
#  ' Racing Dreams ': 2010,
#  ' 180° South ': 2010,
#  ' Sex and the City 2 ': 2010,
#  ' Prince of Persia: The Sands of Time ': 2010,
#  ' Micmacs ': 2010,
#  ' Survival of the Dead ': 2010,
#  ' Agora ': 2010,
#  ' Kites: The Remix ': 2010,
#  ' Marmaduke ': 2010,
#  ' Splice ': 2010,
#  ' Get Him to the Greek ': 2010,
#  ' Killers ': 2010,
#  ' Rosencrantz and Guildenstern Are Undead ': 2010,
#  ' Finding Bliss ': 2010,
#  ' Ondine ': 2010,
#  ' Whiz Kids ': 2010,
#  ' The Karate Kid ': 2010,
#  ' The A-Team ': 2010,
#  ' The Lottery ': 2010,
#  " Winter's Bone ": 2010,
#  ' Coco Chanel & Igor Stravinsky ': 2010,
#  ' Jerusalema ': 2010,
#  ' Joan Rivers: A Piece of Work ': 2010,
#  ' Kings of the Evening ': 2010,
#  ' Stonewall Uprising ': 2010,
#  ' Toy Story 3 ': 2010,
#  ' Jonah Hex ': 2010,
#  ' The Killer Inside Me ': 2010,
#  ' Let It Rain ': 2010,
#  ' Cyrus ': 2010,
#  ' I Am Love ': 2010,
#  ' Raavan ': 2010,
#  ' 8: The Mormon Proposition ': 2010,
#  ' Knight and Day ': 2010,
#  ' Grown Ups ': 2010,
#  ' Eyes Wide Open ': 2010,
#  ' South of the Border ': 2010,
#  ' Dogtooth ': 2010,
#  ' Wild Grass ': 2010,
#  ' Restrepo ': 2010,
#  ' The Twilight Saga: Eclipse ': 2010,
#  ' Love Ranch ': 2010,
#  ' I Hate Luv Storys ': 2010,
#  ' The Last Airbender ': 2010,
#  ' Great Directors ': 2010,
#  ' Grease Sing-A-Long ': 2010,
#  ' Despicable Me ': 2010,
#  ' Predators ': 2010,
#  ' Winnebago Man ': 2010,
#  ' Around a Small Mountain ': 2010,
#  ' [Rec] 2 ': 2010,
#  ' The Kids Are All Right ': 2010,
#  ' The Girl Who Played with Fire ': 2010,
#  " The Sorcerer's Apprentice ": 2010,
#  ' Inception ': 2020,
#  ' Kisses ': 2010,
#  ' Standing Ovation ': 2010,
#  ' Udaan ': 2010,
#  ' Jean-Michel Basquiat: The Radiant Child ': 2010,
#  ' Salt ': 2010,
#  ' Ramona and Beezus ': 2010,
#  ' Life During Wartime ': 2010,
#  ' Farewell ': 2010,
#  ' Countdown to Zero ': 2010,
#  ' Cats & Dogs: The Revenge of Kitty Galore ': 2010,
#  ' Charlie St. Cloud ': 2010,
#  ' Dinner for Schmucks ': 2010,
#  ' Enemies of the People ': 2010,
#  ' The Concert ': 2010,
#  ' The Extra Man ': 2010,
#  ' Hugh Hefner: Playboy, Activist and Rebel ': 2010,
#  ' The Dry Land ': 2010,
#  ' Get Low ': 2010,
#  ' The Sicilian Girl ': 2010,
#  ' The Other Guys ': 2010,
#  ' Step Up 3D ': 2010,
#  ' Cemetery Junction ': 2010,
#  ' Lebanon ': 2010,
#  ' Cairo Time ': 2010,
#  ' Middle Men ': 2010,
#  ' Flipped ': 2010,
#  ' Twelve ': 2010,
#  ' The Disappearance of Alice Creed ': 2010,
#  ' The Wildest Dream ': 2010,
#  ' The Oxford Murders ': 2010,
#  ' Colin Fitz Lives! ': 2010,
#  ' Eat Pray Love ': 2010,
#  ' The Expendables ': 2010,
#  ' Scott Pilgrim vs. the World ': 2010,
#  ' Salt of This Sea ': 2010,
#  ' Neshoba ': 2010,
#  ' Peepli Live ': 2010,
#  ' Animal Kingdom ': 2010,
#  ' Tales from Earthsea ': 2010,
#  ' Vampires Suck ': 2010,
#  ' A Film Unfinished ': 2010,
#  ' Piranha 3D ': 2010,
#  ' Lottery Ticket ': 2010,
#  ' The Switch ': 2010,
#  ' Nanny McPhee Returns ': 2010,
#  ' Soul Kitchen ': 2010,
#  ' Altiplano ': 2010,
#  ' The Tillman Story ': 2010,
#  " Mao's Last Dancer ": 2010,
#  ' Louis ': 2010,
#  ' Takers ': 2010,
#  ' The Last Exorcism ': 2010,
#  ' Change of Plans ': 2010,
#  ' Centurion ': 2010,
#  ' Mesrine: Killer Instinct ': 2010,
#  ' Aashayein ': 2010,
#  ' Chak Jawana ': 2010,
#  ' The American ': 2010,
#  ' My Dog Tulip ': 2010,
#  ' Machete ': 2010,
#  ' Going the Distance ': 2010,
#  ' A Woman, a Gun and a Noodle Shop ': 2010,
#  ' We Are Family ': 2010,
#  ' Last Train Home ': 2010,
#  ' The Winning Season ': 2010,
#  ' Resident Evil: Afterlife 3D ': 2010,
#  ' Genius Within: The Inner Life of Glenn Gould ': 2010,
#  ' The Romantics ': 2010,
#  ' Heartbreaker ': 2010,
#  ' Legendary ': 2010,
#  ' Hideaway ': 2010,
#  " I'm Still Here ": 2010,
#  ' Bran Nue Dae ': 2010,
#  ' Lovely, Still ': 2010,
#  ' Kings of Pastry ': 2010,
#  ' Never Let Me Go ': 2010,
#  ' I Am Comic ': 2010,
#  ' Easy A ': 2010,
#  ' Alpha and Omega ': 2010,
#  ' The Town ': 2010,
#  ' Devil ': 2010,
#  ' Picture Me ': 2010,
#  ' Catfish ': 2010,
#  ' The Freebie ': 2010,
#  ' The Wild Hunt ': 2010,
#  ' Leaves of Grass ': 2010,
#  ' Jack Goes Boating ': 2010,
#  ' You Will Meet A Tall Dark Stranger ': 2010,
#  ' You Again ': 2010,
#  ' Wall Street: Money Never Sleeps ': 2010,
#  ' The Virginity Hit ': 2010,
#  " Legend of the Guardians: The Owls of Ga'Hoole ": 2010,
#  ' Tibet in Song ': 2010,
#  ' Waiting for Superman ': 2010,
#  ' Buried ': 2010,
#  ' Enter the Void ': 2010,
#  ' Howl ': 2010,
#  ' Case 39 ': 2010,
#  ' The Social Network ': 2010,
#  ' Let Me In ': 2010,
#  ' Barry Munday ': 2010,
#  ' Ip Man ': 2010,
#  ' Freakonomics ': 2010,
#  ' Hatchet II ': 2010,
#  ' Speed-Dating ': 2010,
#  ' Chain Letter ': 2010,
#  ' Secretariat ': 2010,
#  ' Life As We Know It ': 2010,
#  " It's Kind of a Funny Story ": 2010,
#  ' My Soul to Take ': 2010,
#  ' Inside Job ': 2010,
#  ' As Good as Dead ': 2010,
#  ' Down Terrace ': 2010,
#  ' Nowhere Boy ': 2010,
#  ' Stone ': 2010,
#  ' Tamara Drewe ': 2010,
#  ' I Spit On Your Grave ': 2010,
#  " It's a Wonderful Afterlife ": 2010,
#  ' Vision ': 2010,
#  ' Red ': 2010,
#  ' Jackass 3D ': 2010,
#  ' Carlos ': 2010,
#  ' Carmo, Hit the Road ': 2010,
#  ' Hereafter ': 2010,
#  ' Conviction ': 2010,
#  ' I Want Your Money ': 2010,
#  ' Samson and Delilah ': 2010,
#  ' The Trouble with Terkel ': 2017,
#  ' White Lion ': 2010,
#  ' Truth In Numbers ': 2010,
#  ' The Last Play at Shea ': 2010,
#  ' Paranormal Activity 2 ': 2010,
#  ' Inhale ': 2010,
#  ' Rising Stars ': 2010,
#  ' Knucklehead ': 2010,
#  ' Saw 3D ': 2010,
#  ' The Kids Grow Up ': 2010,
#  ' Wild Target ': 2010,
#  " The Girl Who Kicked the Hornet's Nest ": 2010,
#  ' Welcome to the Rileys ': 2010,
#  ' Waste Land ': 2010,
#  ' Eichmann ': 2010,
#  ' Monsters ': 2010,
#  ' Shake Hands with the Devil ': 2010,
#  ' Megamind ': 2010,
#  ' For Colored Girls ': 2010,
#  ' Due Date ': 2010,
#  ' Client 9 ': 2010,
#  ' 127 Hours ': 2010,
#  ' Fair Game ': 2010,
#  ' Red Hill ': 2010,
#  ' Four Lions ': 2010,
#  ' Morning Glory ': 2010,
#  ' Unstoppable ': 2010,
#  ' Skyline ': 2010,
#  ' Tiny Furniture ': 2010,
#  ' Helena From the Wedding ': 2010,
#  ' Tangled ': 2010,
#  ' Cool It ': 2010,
#  ' Harry Potter and the Deathly Hallows: Part I ': 2010,
#  ' The Next Three Days ': 2010,
#  ' Heartless ': 2010,
#  ' Made in Dagenham ': 2010,
#  ' White Material ': 2010,
#  ' Guzaarish ': 2010,
#  ' Faster ': 2010,
#  ' Love and Other Drugs ': 2010,
#  ' Burlesque ': 2010,
#  ' The Nutcracker in 3D ': 2010,
#  ' The Legend of Pale Male ': 2010,
#  ' Break Ke Baad ': 2010,
#  ' Undertow ': 2010,
#  " The King's Speech ": 2010,
#  ' About Elly ': 2010,
#  " The Warrior's Way ": 2010,
#  ' I Love You Phillip Morris ': 2010,
#  ' Black Swan ': 2010,
#  ' All Good Things ': 2010,
#  ' Rare Exports: A Christmas Tale ': 2010,
#  ' Dead Awake ': 2017,
#  ' Night Catches Us ': 2010,
#  ' The Chronicles of Narnia: The Voyage of the Dawn Treader ': 2010,
#  ' The Tourist ': 2010,
#  ' Summer Wars ': 2010,
#  ' And Everything Is Going Fine ': 2010,
#  ' The Fighter ': 2010,
#  ' The Tempest ': 2010,
#  " Hemingway's Garden of Eden ": 2010,
#  ' Yogi Bear ': 2010,
#  ' Tron: Legacy ': 2010,
#  ' How Do You Know ': 2010,
#  ' Casino Jack ': 2010,
#  ' Rabbit Hole ': 2010,
#  ' And Soon the Darkness ': 2010,
#  ' True Grit ': 2010,
#  ' Little Fockers ': 2010,
#  ' Country Strong ': 2010,
#  ' Tees Maar Khan ': 2010,
#  ' Somewhere ': 2010,
#  ' Hadewijch ': 2010,
#  ' Secret Sunshine ': 2010,
#  " Gulliver's Travels ": 2010,
#  ' The Illusionist ': 2010,
#  ' Blue Valentine ': 2010,
#  ' Another Year ': 2010,
#  ' If I Want to Whistle, I Whistle ': 2011,
#  ' Phil Ochs: There But For Fortune ': 2011,
#  ' Season of the Witch ': 2011,
#  ' The Time That Remains ': 2011,
#  ' The Absent ': 2011,
#  ' No One Killed Jessica ': 2011,
#  ' The Green Hornet ': 2011,
#  ' The Dilemma ': 2011,
#  ' Plastic Planet ': 2011,
#  ' A Somewhat Gentle Man ': 2011,
#  ' Ong Bak 3 ': 2011,
#  " Barney's Version ": 2011,
#  ' Every Day ': 2018,
#  ' The Heart Specialist ': 2011,
#  ' Burning Palms ': 2011,
#  ' The Way Back ': 2020,
#  ' No Strings Attached ': 2011,
#  ' The Housemaid ': 2011,
#  ' The Company Men ': 2011,
#  ' Dhobi Ghat ': 2011,
#  ' The Rite ': 2011,
#  ' The Mechanic ': 2011,
#  ' Kaboom ': 2011,
#  ' From Prada to Nada ': 2011,
#  ' Biutiful ': 2011,
#  ' Ip Man 2: Legend of the Grandmaster ': 2011,
#  ' Seconds Apart ': 2011,
#  ' Into Eternity ': 2011,
#  ' The Roommate ': 2011,
#  ' Sanctum ': 2011,
#  ' Cold Weather ': 2011,
#  ' The Other Woman ': 2014,
#  ' Waiting for Forever ': 2011,
#  ' Just Go With It ': 2011,
#  ' Gnomeo and Juliet ': 2011,
#  ' The Eagle ': 2011,
#  ' Justin Bieber: Never Say Never ': 2011,
#  ' The Sky Turns ': 2011,
#  ' Vidal Sassoon: The Movie ': 2011,
#  ' Carancho ': 2011,
#  ' Cedar Rapids ': 2011,
#  ' MOOZ-lum ': 2011,
#  ' Unknown ': 2011,
#  ' I Am Number Four ': 2011,
#  ' Big Mommas: Like Father, Like Son ': 2011,
#  ' Now & Later ': 2011,
#  ' Putty Hill ': 2011,
#  ' Vanishing on 7th Street ': 2011,
#  ' The Resident ': 2011,
#  ' The Chaperone ': 2019,
#  ' I Am ': 2011,
#  ' Even the Rain ': 2011,
#  ' The Last Lions ': 2011,
#  ' Brotherhood ': 2011,
#  ' Immigration Tango ': 2011,
#  ' Public Speaking ': 2011,
#  ' Hall Pass ': 2011,
#  ' Drive Angry ': 2011,
#  ' Heartbeats ': 2011,
#  ' Of Gods and Men ': 2011,
#  ' The Grace Card ': 2011,
#  ' Uncle Boonmee Who Can Recall His Past Lives ': 2011,
#  ' Beastly ': 2011,
#  ' Take Me Home Tonight ': 2011,
#  ' Rango ': 2011,
#  ' The Adjustment Bureau ': 2011,
#  ' The Human Resources Manager ': 2011,
#  ' Happythankyoumoreplease ': 2011,
#  ' I Saw the Devil ': 2011,
#  ' Mars Needs Moms! ': 2011,
#  ' Red Riding Hood ': 2011,
#  ' Battle: Los Angeles ': 2011,
#  ' Jane Eyre ': 2011,
#  ' Certified Copy ': 2011,
#  ' Black Death ': 2011,
#  ' Kill the Irishman ': 2011,
#  ' Elektra Luxx ': 2011,
#  ' The Frontier Boys ': 2011,
#  ' Bill Cunningham New York ': 2011,
#  ' The Butcher, The Chef and The Swordsman ': 2011,
#  ' Limitless ': 2011,
#  ' Paul ': 2011,
#  ' The Lincoln Lawyer ': 2011,
#  ' Winter in Wartime ': 2011,
#  ' Cracks ': 2011,
#  ' Desert Flower ': 2011,
#  ' Win Win ': 2011,
#  ' The Music Never Stopped ': 2011,
#  ' My Perestroika ': 2011,
#  ' Diary of a Wimpy Kid: Rodrick Rules ': 2011,
#  ' Sucker Punch ': 2011,
#  ' Korkoro ': 2011,
#  ' Peep World ': 2011,
#  ' Miral ': 2011,
#  ' The 5th Quarter ': 2011,
#  ' Some Days Are Better than Others ': 2011,
#  ' Potiche ': 2011,
#  ' White Irish Drinkers ': 2011,
#  ' Source Code ': 2011,
#  ' Hop ': 2011,
#  ' Insidious ': 2011,
#  ' Circo ': 2011,
#  ' Queen to Play ': 2011,
#  ' Super ': 2011,
#  ' Trust ': 2011,
#  ' The Last Godfather ': 2011,
#  ' Wrecked ': 2011,
#  ' Rubber ': 2011,
#  ' In a Better World ': 2011,
#  ' Cat Run ': 2011,
#  ' Soul Surfer ': 2011,
#  ' Your Highness ': 2011,
#  ' Arthur ': 2011,
#  ' Hanna ': 2011,
#  ' Ceremony ': 2011,
#  " Meek's Cutoff ": 2011,
#  ' American: The Bill Hicks Story ': 2011,
#  ' Meeting Spencer ': 2011,
#  ' Meet Monica Velour ': 2011,
#  ' Born to be Wild ': 2011,
#  ' No Eres Tú, Soy Yo ': 2011,
#  " They're Out Of The Business ": 2011,
#  ' Thank You ': 2011,
#  ' A Screaming Man ': 2011,
#  ' Rio ': 2011,
#  ' The Conspirator ': 2011,
#  ' Scream 4 ': 2011,
#  ' Square Grouper ': 2011,
#  ' The Princess of Montpensier ': 2011,
#  ' Atlas Shrugged Part 1 ': 2011,
#  ' The Double Hour ': 2011,
#  ' Armadillo ': 2011,
#  ' Fly Away ': 2011,
#  ' The Imperialists Are Still Alive! ': 2011,
#  ' Dumbstruck ': 2011,
#  ' African Cats ': 2011,
#  " Tyler Perry's Madea's Big Happy Family ": 2011,
#  ' Water for Elephants ': 2011,
#  ' Stake Land ': 2011,
#  ' When Harry Tries To Marry ': 2011,
#  ' Incendies ': 2011,
#  ' POM Wonderful Presents: The Greatest Movie Ever Sold ': 2011,
#  ' The Bang Bang Club ': 2011,
#  ' Applause ': 2011,
#  ' The Warring States ': 2011,
#  ' Dum Maaro Dum ': 2011,
#  ' Legend of the Fist: The Return of Chen Zhen ': 2011,
#  ' The Scenesters ': 2011,
#  ' Zokkomon ': 2011,
#  ' Grave Encounters ': 2011,
#  ' The Arbor ': 2011,
#  ' Fast Five ': 2011,
#  ' Hoodwinked Too! Hood vs. Evil ': 2011,
#  ' Prom ': 2011,
#  ' Dylan Dog: Dead of Night ': 2011,
#  ' earthwork ': 2011,
#  ' 13 Assassins ': 2011,
#  " That's What I Am ": 2011,
#  ' Exporting Raymond ': 2011,
#  ' Sympathy for Delicious ': 2011,
#  ' Lebanon, Pa. ': 2011,
#  ' Cave of Forgotten Dreams ': 2011,
#  ' Rammbock: Berlin Undead ': 2011,
#  ' Thor ': 2011,
#  ' Jumping the Broom ': 2011,
#  ' Something Borrowed ': 2011,
#  ' Octubre ': 2011,
#  ' An Invisible Sign ': 2011,
#  ' Vito Bonafacci ': 2011,
#  ' Daydream Nation ': 2011,
#  ' Passion Play ': 2011,
#  ' There Be Dragons ': 2011,
#  ' Caterpillar ': 2011,
#  ' Haunted 3D ': 2011,
#  ' Last Night ': 2011,
#  ' The Beaver ': 2011,
#  ' The Edge ': 2011,
#  ' Bridesmaids ': 2011,
#  ' Priest ': 2011,
#  ' How to Live Forever ': 2011,
#  ' Cameraman: The Life and Work of Jack Cardiff ': 2011,
#  ' Topp Twins: Untouchable Girls ': 2011,
#  " L'Amour Fou ": 2011,
#  ' The Big Bang ': 2011,
#  ' The First Grader ': 2011,
#  ' Hey, Boo: Harper Lee and To Kill a Mockingbird ': 2011,
#  ' The High Cost of Living ': 2011,
#  ' Hesher ': 2011,
#  " Brother's Justice ": 2011,
#  ' True Legend ': 2011,
#  ' The Bleeding House ': 2011,
#  ' Everything Must Go ': 2011,
#  ' Go for It! ': 2011,
#  ' Louder Than a Bomb ': 2011,
#  ' Pirates of the Caribbean: On Stranger Tides ': 2011,
#  ' Bloodworth ': 2011,
#  ' 35 and Ticking ': 2011,
#  ' Cost of a Soul ': 2011,
#  ' Midnight in Paris ': 2011,
#  ' Tuesday, After Christmas ': 2011,
#  ' The Hangover Part II ': 2011,
#  ' Kung Fu Panda 2 ': 2011,
#  ' We Are the Night ': 2011,
#  ' The Tree of Life ': 2011,
#  ' Small Town Murder Songs ': 2011,
#  ' Puzzle ': 2018,
#  ' United Red Army ': 2011,
#  ' !Women Art Revolution ': 2011,
#  ' YellowBrickRoad ': 2011,
#  ' X-Men: First Class ': 2011,
#  ' Film Socialisme ': 2011,
#  ' Rejoice and Shout ': 2011,
#  ' The Last Mountain ': 2011,
#  ' Submarine ': 2011,
#  ' Beautiful Boy ': 2018,
#  ' Beginners ': 2011,
#  ' Love, Wedding, Marriage ': 2011,
#  ' Empire of Silver ': 2011,
#  ' The Lion of Judah ': 2011,
#  ' The Wave ': 2020,
#  ' Judy Moody And The NOT Bummer Summer ': 2011,
#  ' Super 8 ': 2011,
#  ' Road to Nowhere ': 2011,
#  ' The Trip ': 2011,
#  ' Troll Hunter ': 2011,
#  ' Bride Flight ': 2011,
#  ' Viva Riva! ': 2011,
#  ' Just Like Us ': 2011,
#  ' Green Lantern ': 2011,
#  " Mr. Popper's Penguins ": 2011,
#  ' Page One: A Year Inside the New York Times ': 2011,
#  ' Buck ': 2011,
#  ' Kidnapped ': 2011,
#  ' The Art of Getting By ': 2011,
#  ' If a Tree Falls: A Story of the Earth Liberation Front ': 2011,
#  ' Cars 2 ': 2011,
#  ' Bad Teacher ': 2011,
#  ' A Love Affair of Sorts ': 2011,
#  ' General Orders No. 9 ': 2011,
#  ' A Better Life ': 2011,
#  ' Double Dhamaal ': 2011,
#  ' Turtle: The Incredible Journey ': 2011,
#  " Conan O'Brien Can't Stop ": 2011,
#  ' Transformers: Dark of the Moon ': 2011,
#  ' Larry Crowne ': 2011,
#  ' Monte Carlo ': 2011,
#  ' Love Etc. ': 2011,
#  ' Crime After Crime ': 2011,
#  ' The Perfect Host ': 2011,
#  ' Terri ': 2011,
#  ' Rapt ': 2011,
#  ' Septien ': 2011,
#  ' Zookeeper ': 2011,
#  ' Horrible Bosses ': 2011,
#  ' The Chameleon ': 2011,
#  ' Beats, Rhymes and Life: The Travels of a Tribe Called Quest ': 2011,
#  ' The Ledge ': 2011,
#  ' Project Nim ': 2011,
#  ' The Ward ': 2011,
#  ' Phase 7 ': 2011,
#  ' Harry Potter and the Deathly Hallows: Part II ': 2011,
#  ' Winnie the Pooh ': 2011,
#  ' Girlfriend ': 2011,
#  ' The Tree ': 2011,
#  ' Lucky ': 2017,
#  ' Salvation Boulevard ': 2011,
#  ' Life, Above All ': 2011,
#  ' Snow Flower and the Secret Fan ': 2011,
#  ' Tabloid ': 2011,
#  ' The Undefeated ': 2011,
#  ' Captain America: The First Avenger ': 2011,
#  ' Friends with Benefits ': 2011,
#  ' The Myth of the American Sleepover ': 2011,
#  " Sarah's Key ": 2011,
#  ' Another Earth ': 2011,
#  ' Singham ': 2011,
#  ' A Little Help ': 2011,
#  ' El Bulli: Cooking in Progress ': 2011,
#  ' Life in a Day ': 2011,
#  ' Crazy, Stupid, Love ': 2011,
#  ' Cowboys and Aliens ': 2011,
#  ' The Smurfs ': 2011,
#  ' The Future ': 2011,
#  ' All She Can ': 2011,
#  ' The Guard ': 2011,
#  " The Devil's Double ": 2011,
#  ' Good Neighbors ': 2011,
#  ' Without Men ': 2011,
#  ' Attack the Block ': 2011,
#  ' Point Blank ': 2019,
#  ' The Change-Up ': 2011,
#  ' Rise of the Planet of the Apes ': 2011,
#  ' Mysteries of Lisbon ': 2011,
#  ' Bellflower ': 2011,
#  ' The Perfect Age of Rock And Roll ': 2011,
#  ' The Whistleblower ': 2011,
#  ' Magic Trip ': 2011,
#  ' The Help ': 2011,
#  ' Final Destination 5 ': 2011,
#  ' 30 Minutes or Less ': 2011,
#  ' Glee: The 3D Concert Movie ': 2011,
#  ' The Last Circus ': 2011,
#  ' Vigilante Vigilante ': 2011,
#  ' Senna ': 2011,
#  ' Atrocious ': 2011,
#  ' Conan The Barbarian ': 2011,
#  ' One Day ': 2011,
#  ' Spy Kids: All the Time in the World ': 2011,
#  ' Fright Night ': 2011,
#  ' Programming the Nation? ': 2011,
#  ' 5 Days of War ': 2011,
#  ' The Hedgehog ': 2011,
#  ' Flypaper ': 2011,
#  " Mozart's Sister ": 2011,
#  ' Amigo ': 2011,
#  ' S** and Zen 3D: Extreme Ecstasy ': 2011,
#  ' Griff the Invisible ': 2011,
#  ' The Mistaken ': 2011,
#  " Don't Be Afraid of the Dark ": 2011,
#  ' Our Idiot Brother ': 2011,
#  ' Colombiana ': 2011,
#  ' Suing The Devil ': 2011,
#  ' Circumstance ': 2011,
#  ' Higher Ground ': 2011,
#  ' BuzzKill ': 2011,
#  ' Swinging with the Finkels ': 2011,
#  ' Brighton Rock ': 2011,
#  ' Chasing Madoff ': 2011,
#  ' Rebirth ': 2011,
#  ' Special Treatment ': 2011,
#  ' Redemption Road ': 2011,
#  ' The Caller ': 2011,
#  ' The Family Tree ': 2011,
#  ' The Debt ': 2011,
#  ' Bodyguard ': 2011,
#  ' Gainsbourg ': 2011,
#  ' Shark Night 3D ': 2011,
#  ' Apollo 18 ': 2011,
#  ' Insight ': 2011,
#  ' Saving Private Perez ': 2011,
#  ' A Good Old Fashioned Orgy ': 2011,
#  ' Love Crime ': 2011,
#  ' Warrior ': 2011,
#  ' Bucky Larson: Born to Be a Star ': 2011,
#  ' Contagion ': 2011,
#  ' Where Soldiers Come From ': 2011,
#  ' Burke and Hare ': 2011,
#  ' The Black Power Mixtape 1967-1975 ': 2011,
#  ' Main Street ': 2011,
#  ' Mere Brother Ki Dulhan ': 2011,
#  ' Shaolin ': 2011,
#  ' The Afterlight ': 2011,
#  ' Laugh At My Pain ': 2011,
#  ' The Whale ': 2011,
#  ' Tanner Hall ': 2011,
#  ' Creature ': 2011,
#  ' Granito: How To Nail A Dictator ': 2011,
#  ' Straw Dogs ': 2011,
#  ' Drive ': 2011,
#  " I Don't Know How She Does It ": 2011,
#  ' Back Door Channels: The Price of Peace ': 2011,
#  ' Restless ': 2011,
#  ' Hermano ': 2011,
#  ' Connected ': 2011,
#  ' Happy, Happy ': 2011,
#  " Jane's Journey ": 2011,
#  ' Stay Cool ': 2011,
#  ' My Afternoons With Marguerite ': 2011,
#  ' The Weird World of Blowfly ': 2011,
#  ' Pearl Jam Twenty ': 2011,
#  ' Shit Year ': 2011,
#  ' Dolphin Tale ': 2011,
#  ' Moneyball ': 2011,
#  ' Abduction ': 2011,
#  ' Killer Elite ': 2011,
#  ' Weekend ': 2011,
#  ' The Man Nobody Knew: In Search of My Father, CIA Spymaster William Colby ': 2011,
#  ' Machine Gun Preacher ': 2011,
#  ' Mardi Gras: Spring Break ': 2011,
#  ' Puncture ': 2011,
#  ' Limelight ': 2011,
#  ' A Bird of the Air ': 2011,
#  ' Red State ': 2011,
#  ' Thunder Soul ': 2011,
#  ' U.N. Me ': 2011,
#  " Archie's Final Project ": 2011,
#  ' Courageous ': 2011,
#  " What's Your Number? ": 2011,
#  ' Dream House ': 2011,
#  ' 50/50 ': 2011,
#  ' Margaret ': 2011,
#  ' Take Shelter ': 2011,
#  ' Thru the Moebius Strip ': 2011,
#  ' Tucker and Dale vs. Evil ': 2011,
#  ' Sarah Palin: You Betcha! ': 2011,
#  ' Finding Joe ': 2011,
#  ' Munger Road ': 2011,
#  ' Benda Bilili! ': 2011,
#  ' Giorgio Moroder Presents Metropolis ': 2011,
#  ' Real Steel ': 2011,
#  ' The Ides of March ': 2011,
#  ' Blackthorn ': 2011,
#  ' 1911 ': 2011,
#  ' Dirty Girl ': 2011,
#  ' The Way ': 2011,
#  ' Flying Monsters 3D ': 2011,
#  ' The Human Centipede Part 2 (Full Sequence) ': 2011,
#  ' The Women on the 6th Floor ': 2011,
#  ' Footloose ': 2011,
#  ' The Big Year ': 2011,
#  ' The Thing ': 2011,
#  ' Oka! ': 2011,
#  ' Chalet Girl ': 2011,
#  ' Texas Killing Fields ': 2011,
#  ' The Skin I Live In ': 2011,
#  ' Trespass ': 2011,
#  ' Labios Rojos ': 2011,
#  ' The Woman ': 2011,
#  ' Father of Invention ': 2011,
#  ' Paul Goodman Changed My Life ': 2011,
#  ' The Catechism Cataclysm ': 2011,
#  ' The Mighty Macs ': 2011,
#  ' The Three Musketeers ': 2011,
#  ' Johnny English Reborn ': 2011,
#  ' Paranormal Activity 3 ': 2011,
#  ' Elevate ': 2011,
#  " Being Elmo: A Puppeteer's Journey ": 2011,
#  ' Martha Marcy May Marlene ': 2011,
#  ' Snowmen ': 2011,
#  ' Margin Call ': 2011,
#  ' Oranges and Sunshine ': 2011,
#  ' Sidewalls ': 2011,
#  ' Puss in Boots ': 2011,
#  ' The Rum Diary ': 2011,
#  ' In Time ': 2011,
#  ' My Reincarnation ': 2011,
#  ' The Double ': 2014,
#  ' Restitution ': 2011,
#  ' Like Crazy ': 2017,
#  " All's Faire in Love ": 2011,
#  ' Anonymous ': 2016,
#  ' Inni ': 2011,
#  ' Five Star Day ': 2011,
#  ' Tower Heist ': 2011,
#  ' A Very Harold & Kumar 3D Christmas ': 2011,
#  ' 13 ': 2011,
#  ' Young Goethe in Love ': 2011,
#  ' The Son of No One ': 2011,
#  ' Another Happy Day ': 2011,
#  ' Charlotte Rampling: The Look ': 2011,
#  ' Killing Bono ': 2011,
#  ' J. Edgar ': 2011,
#  ' Jack and Jill ': 2011,
#  ' Immortals ': 2011,
#  ' London Boulevard ': 2011,
#  ' Melancholia ': 2011,
#  ' Dog Sweat ': 2011,
#  ' Eames: The Architect and the Painter ': 2011,
#  ' 11-11-11 ': 2011,
#  ' The Greening of Whitney Brown ': 2011,
#  ' The Conquest ': 2011,
#  ' Into the Abyss ': 2011,
#  ' Elite Squad: The Enemy Within ': 2011,
#  ' The Descendants ': 2011,
#  ' Happy Feet Two ': 2011,
#  ' The Twilight Saga: Breaking Dawn Part 1 ': 2011,
#  ' Garbo: The Spy ': 2011,
#  ' The Heir Apparent: Largo Winch ': 2011,
#  ' Tyrannosaur ': 2011,
#  ' Arthur Christmas ': 2011,
#  ' The Muppets ': 2011,
#  ' Hugo ': 2011,
#  ' A Dangerous Method ': 2011,
#  ' Rampart ': 2011,
#  ' My Week With Marilyn ': 2011,
#  ' The Artist ': 2011,
#  ' Sleeping Beauty ': 2011,
#  ' Redline ': 2011,
#  ' Shame ': 2011,
#  " A Warrior's Heart ": 2011,
#  ' Answers to Nothing ': 2011,
#  ' Outrage ': 2011,
#  ' Pastorela ': 2011,
#  ' The Sitter ': 2011,
#  " New Year's Eve ": 2011,
#  ' W.E. ': 2011,
#  ' In Darkness ': 2011,
#  ' Tinker, Tailor, Soldier, Spy ': 2011,
#  ' We Need to Talk About Kevin ': 2011,
#  ' Young Adult ': 2011,
#  ' Catch .44 ': 2011,
#  ' Ladies vs. Ricky Bahl ': 2011,
#  ' I Melt With You ': 2011,
#  ' Addiction Incorporated ': 2011,
#  ' Alvin and the Chipmunks: Chipwrecked ': 2011,
#  ' Sherlock Holmes: A Game of Shadows ': 2011,
#  ' Cook County ': 2011,
#  ' Carnage ': 2011,
#  ' Mission: Impossible Ghost Protocol ': 2011,
#  " Corman's World's: Exploits of a Hollywood Rebel ": 2011,
#  ' The Adventures of Tintin ': 2011,
#  ' Albert Nobbs ': 2011,
#  ' We Bought a Zoo ': 2011,
#  ' In the Land of Blood and Honey ': 2011,
#  ' Pina ': 2011,
#  ' Don 2 ': 2011,
#  ' War Horse ': 2011,
#  ' The Darkest Hour ': 2011,
#  ' Newlyweds ': 2011,
#  ' Pariah ': 2011,
#  ' The Iron Lady ': 2011,
#  ' A Separation ': 2011,
#  ' Angels Crest ': 2011,
#  ' The Devil Inside ': 2012,
#  ' Roadie ': 2012,
#  ' Beneath the Darkness ': 2012,
#  ' Norwegian Wood ': 2012,
#  ' Loosies ': 2012,
#  ' Joyful Noise ': 2012,
#  ' Contraband ': 2012,
#  ' Beauty and the Beast 3D ': 2012,
#  ' Albatross ': 2012,
#  ' Man on a Mission ': 2012,
#  ' The Divide ': 2012,
#  " Don't Go in the Woods ": 2012,
#  ' Underworld: Awakening ': 2012,
#  ' Haywire ': 2012,
#  ' Red Tails ': 2012,
#  ' The Flowers of War ': 2012,
#  ' Coriolanus ': 2012,
#  ' Carol Channing: Larger Than Life ': 2012,
#  ' Miss Bala ': 2019,
#  ' Man on a Ledge ': 2012,
#  ' One for the Money ': 2012,
#  ' The Grey ': 2012,
#  ' Amador ': 2012,
#  ' Declaration of War ': 2012,
#  ' The Wicker Tree ': 2012,
#  ' Big Miracle ': 2012,
#  ' The Woman in Black ': 2012,
#  ' Chronicle ': 2012,
#  ' Windfall ': 2012,
#  ' Kill List ': 2012,
#  ' The Innkeepers ': 2012,
#  ' I Am Bruce Lee ': 2012,
#  ' Safe House ': 2012,
#  ' Journey 2: The Mysterious Island ': 2012,
#  ' Star Wars: Episode I - The Phantom Menace 3D ': 2012,
#  ' The Vow ': 2012,
#  ' Perfect Sense ': 2012,
#  ' Ek Main Aur Ekk Tu ': 2012,
#  ' Return ': 2012,
#  ' Michael ': 2012,
#  ' Deadline ': 2012,
#  ' The Secret World of Arrietty ': 2012,
#  ' This Means War ': 2012,
#  ' Ghost Rider: Spirit of Vengeance ': 2012,
#  ' Thin Ice ': 2012,
#  " Putin's Kiss ": 2012,
#  ' Bullhead ': 2012,
#  ' Undefeated ': 2012,
#  ' Wanderlust ': 2012,
#  ' Gone ': 2012,
#  ' Good Deeds ': 2012,
#  ' Act of Valor ': 2012,
#  ' The Forgiveness of Blood ': 2012,
#  ' Tere Naal Love Ho Gaya ': 2012,
#  ' Tomorrow, When the War Began ': 2012,
#  ' Project X ': 2012,
#  " Dr. Seuss' The Lorax ": 2012,
#  ' Boy ': 2012,
#  ' The Salt of Life ': 2012,
#  ' Last Days Here ': 2012,
#  ' The Snowtown Murders ': 2012,
#  ' Being Flynn ': 2012,
#  " Tim and Eric's Billion Dollar Movie ": 2012,
#  ' Let the Bullets Fly ': 2012,
#  ' Art Is...The Permanent Revolution ': 2012,
#  ' John Carter ': 2012,
#  ' A Thousand Words ': 2012,
#  ' Silent House ': 2012,
#  ' The Decoy Bride ': 2012,
#  ' Footnote ': 2012,
#  ' Friends with Kids ': 2012,
#  ' Salmon Fishing in the Yemen ': 2012,
#  ' Playback ': 2012,
#  ' Sound of Noise ': 2012,
#  ' Jiro Dreams of Sushi ': 2012,
#  ' 21 Jump Street ': 2012,
#  ' Detachment ': 2012,
#  ' Around June ': 2012,
#  ' Ranchero ': 2012,
#  ' Seeking Justice ': 2012,
#  ' Casa de Mi Padre ': 2012,
#  ' Delicacy ': 2012,
#  ' Jeff Who Lives at Home ': 2012,
#  ' The Hunger Games ': 2012,
#  ' Brake ': 2012,
#  ' The Trouble With Bliss ': 2012,
#  ...}

# %%
print("len() method :", len(dict))
# Out:
# len() method : 5947

# %%
a_file = open("moviecompiledata.csv", "w")

writer = csv.writer(a_file)
for key, value in dict.items():
    writer.writerow([key, value])

a_file.close()
